# %% [markdown]
# # 01 - Stock Market Data Loading & Ingestion
# This notebook demonstrates loading raw stock market data from Yahoo Finance and saving it to our raw data repository.

# %%
import sys
import os
# Add the project root directory to the python path
sys.path.append(os.path.abspath('..'))

# %%
from src.ingestion.data_loader import fetch_stock_data, save_raw_data
from config.config import TICKERS, START_DATE, END_DATE

# %%
# Fetch historical data using configuration parameters
raw_df = fetch_stock_data(tickers=TICKERS, start=START_DATE, end=END_DATE)

# %%
# Save raw yfinance data (with MultiIndex) to the data/raw folder
save_raw_data(raw_df)

# %%
# Display raw data structure
raw_df.head()
